# %%
# %pip install "mlflow-skinny[databricks]>=2.4.1"
dbutils.library.restartPython()

# %%
import mlflow
catalog = "datacartel_dbx"
schema = "havg_data"
model_name = "customerchurnxgbclassifier"
model_uri = "models:/m-ced050f7c6de4b38870286507e393389"
mlflow.set_registry_uri("databricks-uc")
mlflow.register_model(model_uri=model_uri, name=f"{catalog}.{schema}.{model_name}")
