# %%
import mlflow
# import mlflow.sklearn
import optuna

from optuna.integration.mlflow import MLflowCallback
from optuna.pruners import MedianPruner

import numpy as np
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import StratifiedKFold, cross_val_score

from sklearn.preprocessing import (
    StandardScaler,
    MinMaxScaler,
    RobustScaler,
    OneHotEncoder
)

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

import json

# %%
X_train = pd.read_csv("../data/processed/raw_features/X_train.csv")
X_test = pd.read_csv("../data/processed/raw_features/X_test.csv")
y_train = pd.read_csv("../data/processed/target/y_train.csv").squeeze()
y_test = pd.read_csv("../data/processed/target/y_test.csv").squeeze()

# %%
# =========================================================
# Columns
# =========================================================

nomod_columns = [
    'HasCrCard',
    'IsActiveMember',
]

dummyfy_columns = [
    'Card Type',
    'NumOfProducts',
    'Geography',
    'Gender'
]

norm_std_columns = [
    'Balance',
    'Point Earned',
    'CreditScore',
    'Age',
    'Tenure',
    'Satisfaction Score',
    'EstimatedSalary'
]

# %%
# =========================================================
# Config
# =========================================================

RANDOM_STATE = 42
N_SPLITS = 5

EXPERIMENT_NAME = "customer-churn-optuna"

# %% [markdown]
# engineer features.
# find shap_values to determine most important features
#
# set optuna and mlflow.

# %%
# =========================================================
# Build Pipeline
# =========================================================

def build_pipeline(trial):

    # -----------------------------
    # Preprocessing
    # -----------------------------

    scaler_name = trial.suggest_categorical(
        'scaler',
        ['std', 'minmax', 'robust']
    )

    encoder_name = trial.suggest_categorical(
        'encoder',
        ['drop_first', 'no_drop']
    )

    scalers = {
        'std': StandardScaler(),
        'minmax': MinMaxScaler(),
        'robust': RobustScaler()
    }

    scaler = scalers[scaler_name]

    encoder = OneHotEncoder(
        handle_unknown='ignore',
        drop='first' if encoder_name == 'drop_first' else None
    )

    preprocessor = ColumnTransformer(
    transformers=[
        ('cat', encoder, dummyfy_columns),
        ('num', scaler, norm_std_columns),
        ('pass', 'passthrough', nomod_columns)
    ],
    remainder='drop'   # explicit is better than implicit
)

    # -----------------------------
    # Model Selection
    # -----------------------------

    model_name = trial.suggest_categorical(
        'model',
        ['lr', 'dt', 'rf']
    )

    if model_name == 'lr':

        model = LogisticRegression(
            C=trial.suggest_float(
                'lr_C',
                1e-3,
                10,
                log=True
            ),
            solver='lbfgs',
            max_iter=2000,
            random_state=RANDOM_STATE
        )

    elif model_name == 'dt':

        model = DecisionTreeClassifier(
            max_depth=trial.suggest_int(
                'dt_max_depth',
                2,
                20
            ),
            min_samples_split=trial.suggest_int(
                'dt_min_samples_split',
                2,
                20
            ),
            min_samples_leaf=trial.suggest_int(
                'dt_min_samples_leaf',
                1,
                10
            ),
            random_state=RANDOM_STATE
        )

    else:

        model = RandomForestClassifier(
            n_estimators=trial.suggest_int(
                'rf_n_estimators',
                100,
                500
            ),
            max_depth=trial.suggest_int(
                'rf_max_depth',
                2,
                20
            ),
            min_samples_split=trial.suggest_int(
                'rf_min_samples_split',
                2,
                20
            ),
            min_samples_leaf=trial.suggest_int(
                'rf_min_samples_leaf',
                1,
                10
            ),
            random_state=RANDOM_STATE,
            n_jobs=-1
        )

    # -----------------------------
    # Full Pipeline
    # -----------------------------

    pipeline = Pipeline([
        ('preprocessing', preprocessor),
        ('model', model)
    ])

    return pipeline

# %%
# =========================================================
# Objective Function
# =========================================================

def objective(trial):

    pipeline = build_pipeline(trial)

    cv = StratifiedKFold(
        n_splits=N_SPLITS,
        shuffle=True,
        random_state=RANDOM_STATE
    )

    scores = cross_val_score(
        pipeline,
        X_train,
        y_train,
        scoring='average_precision',
        cv=cv,
        n_jobs=-1
    )

    mean_auc = np.mean(scores)

    # --------------------------------
    # Report intermediate value
    # (for pruning)
    # --------------------------------

    trial.report(mean_auc, step=0)

    if trial.should_prune():
        raise optuna.TrialPruned()

    return mean_auc

# %%
# =========================================================
# MLflow Setup
# =========================================================

import os

ROOT_DIR = os.path.abspath("../")  # or your project root explicitly
MLRUNS_DIR = os.path.join(ROOT_DIR, "mlruns")

mlflow.set_tracking_uri(f"file:{MLRUNS_DIR}")
mlflow.set_experiment(EXPERIMENT_NAME)

mlflc = MLflowCallback(
    tracking_uri=mlflow.get_tracking_uri(),
    metric_name="average_precision",
    create_experiment=False,
    mlflow_kwargs={"nested": True}
)


# =========================================================
# Study
# =========================================================

study = optuna.create_study(
    direction='maximize',
    pruner=MedianPruner(
        n_startup_trials=5,
        n_warmup_steps=0
    )
)
# Out:
# /var/folders/bv/50x24wc545x5mclk_t88ryrc0000gn/T/ipykernel_81542/346104196.py:13: ExperimentalWarning: MLflowCallback is experimental (supported from v1.4.0). The interface can change in the future.
#   mlflc = MLflowCallback(
# [I 2026-05-21 18:43:59,856] A new study created in memory with name: no-name-56d15da8-029d-40b1-bb0b-bd848810d4ad

# %%
def get_feature_names(preprocessor):
    # Works only after fitting
    feature_names = preprocessor.get_feature_names_out()

    # sklearn returns names like:
    # "cat__Geography_France", "num__Balance", etc.
    return feature_names

# %%
# =========================================================
# Run Optimization
# =========================================================

with mlflow.start_run(run_name="optuna_search"):

    study.optimize(
        objective,
        n_trials=250,
        callbacks=[mlflc]
    )

    # --------------------------------
    # Best Metrics
    # --------------------------------

    mlflow.log_metric(
        "best_auc",
        study.best_value
    )

    # --------------------------------
    # Best Params
    # --------------------------------

    mlflow.log_params(study.best_params)

    # --------------------------------
    # Train Best Pipeline
    # --------------------------------

    best_pipeline = build_pipeline(study.best_trial)

    best_pipeline.fit(X_train, y_train)

    preprocessor = best_pipeline.named_steps['preprocessing']

    # --------------------------------
    # log feature names
    # --------------------------------
    # BEFORE columns
    input_features = dummyfy_columns + norm_std_columns + nomod_columns

    # AFTER columns
    output_features = get_feature_names(preprocessor)

    mlflow.log_param("n_input_features", len(input_features))
    mlflow.log_param("n_output_features", len(output_features))
    mlflow.log_dict({
        "input_features": input_features,
        "output_features": output_features
    }, "feature_schema.json")


    # --------------------------------
    # log Metrics
    # --------------------------------
    y_pred = best_pipeline.predict(X_test)
    y_proba = best_pipeline.predict_proba(X_test)[:, 1]

    mlflow.log_metrics({
        "test_accuracy": accuracy_score(y_test, y_pred),
        "test_precision": precision_score(y_test, y_pred),
        "test_recall": recall_score(y_test, y_pred),
        "test_f1": f1_score(y_test, y_pred),
        "test_auc": roc_auc_score(y_test, y_proba),
        "train_accuracy": accuracy_score(y_test, y_pred),
        "train_precision": precision_score(y_test, y_pred),
        "train_recall": recall_score(y_test, y_pred),
        "train_f1": f1_score(y_test, y_pred),
        "rain_auc": roc_auc_score(y_test, y_proba),
    })

    mlflow.log_dict(
        classification_report(y_test, y_pred, output_dict=True),
        "classification_report.json"
    )

    mlflow.log_dict(
        confusion_matrix(y_test, y_pred).tolist(),
        "confusion_matrix.json"
    )

    # --------------------------------
    # Save Best Model
    # --------------------------------

    mlflow.sklearn.log_model(
        sk_model=best_pipeline,
        name="best_model",
        #artifact_path="best_model", # artifact_path deprecated soon
        serialization_format="skops"
    )
# Out:
# [I 2026-05-21 18:43:59,920] Trial 0 finished with value: 0.6152744880048263 and parameters: {'scaler': 'minmax', 'encoder': 'no_drop', 'model': 'dt', 'dt_max_depth': 5, 'dt_min_samples_split': 6, 'dt_min_samples_leaf': 9}. Best is trial 0 with value: 0.6152744880048263.
# [I 2026-05-21 18:44:00,275] Trial 1 finished with value: 0.6740164905128255 and parameters: {'scaler': 'robust', 'encoder': 'no_drop', 'model': 'rf', 'rf_n_estimators': 158, 'rf_max_depth': 10, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 8}. Best is trial 1 with value: 0.6740164905128255.
# [I 2026-05-21 18:44:00,321] Trial 2 finished with value: 0.6146925938213057 and parameters: {'scaler': 'std', 'encoder': 'no_drop', 'model': 'lr', 'lr_C': 0.502876084135564}. Best is trial 1 with value: 0.6740164905128255.
# [I 2026-05-21 18:44:00,575] Trial 3 finished with value: 0.6704426048348475 and parameters: {'scaler': 'robust', 'encoder': 'no_drop', 'model': 'rf', 'rf_n_estimators': 105, 'rf_max_depth': 18, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10}. Best is trial 1 with value: 0.6740164905128255.
# [I 2026-05-21 18:44:01,026] Trial 4 finished with value: 0.6741138280511138 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 193, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8}. Best is trial 4 with value: 0.6741138280511138.
# [I 2026-05-21 18:44:01,081] Trial 5 pruned.
# [I 2026-05-21 18:44:01,858] Trial 6 pruned.
# [I 2026-05-21 18:44:01,915] Trial 7 pruned.
# [I 2026-05-21 18:44:01,973] Trial 8 pruned.
# [I 2026-05-21 18:44:02,030] Trial 9 pruned.
# [I 2026-05-21 18:44:02,075] Trial 10 pruned.
# [I 2026-05-21 18:44:02,441] Trial 11 finished with value: 0.6800984015922806 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 156, 'rf_max_depth': 10, 'rf_min_samples_split': 16, 'rf_min_samples_leaf': 6}. Best is trial 11 with value: 0.6800984015922806.
# [I 2026-05-21 18:44:03,022] Trial 12 finished with value: 0.6813666432490735 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 231, 'rf_max_depth': 11, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 4}. Best is trial 12 with value: 0.6813666432490735.
# [I 2026-05-21 18:44:03,627] Trial 13 finished with value: 0.6852226617170276 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 282, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 3}. Best is trial 13 with value: 0.6852226617170276.
# [I 2026-05-21 18:44:04,156] Trial 14 pruned.
# [I 2026-05-21 18:44:04,852] Trial 15 finished with value: 0.6819017991743311 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 292, 'rf_max_depth': 14, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 2}. Best is trial 13 with value: 0.6852226617170276.
# [I 2026-05-21 18:44:04,908] Trial 16 pruned.
# [I 2026-05-21 18:44:05,700] Trial 17 finished with value: 0.6854945736542167 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 323, 'rf_max_depth': 16, 'rf_min_samples_split': 15, 'rf_min_samples_leaf': 1}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:06,636] Trial 18 finished with value: 0.6822567548041404 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 385, 'rf_max_depth': 20, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 1}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:07,433] Trial 19 pruned.
# [I 2026-05-21 18:44:07,479] Trial 20 pruned.
# [I 2026-05-21 18:44:08,441] Trial 21 finished with value: 0.6822041930356177 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 397, 'rf_max_depth': 20, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 1}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:09,386] Trial 22 finished with value: 0.6821961714234519 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 380, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:10,042] Trial 23 pruned.
# [I 2026-05-21 18:44:10,783] Trial 24 finished with value: 0.6831452513466878 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 398, 'rf_max_depth': 7, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 1}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:11,617] Trial 25 pruned.
# [I 2026-05-21 18:44:12,275] Trial 26 pruned.
# [I 2026-05-21 18:44:12,947] Trial 27 finished with value: 0.6820425524365094 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 276, 'rf_max_depth': 13, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 2}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:13,784] Trial 28 finished with value: 0.6829683490056617 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 427, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 3}. Best is trial 17 with value: 0.6854945736542167.
# [I 2026-05-21 18:44:13,830] Trial 29 pruned.
# [I 2026-05-21 18:44:13,900] Trial 30 pruned.
# [I 2026-05-21 18:44:14,691] Trial 31 pruned.
# [I 2026-05-21 18:44:15,522] Trial 32 finished with value: 0.685607272266892 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 421, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1}. Best is trial 32 with value: 0.685607272266892.
# [I 2026-05-21 18:44:16,319] Trial 33 pruned.
# [I 2026-05-21 18:44:16,821] Trial 34 pruned.
# [I 2026-05-21 18:44:17,342] Trial 35 finished with value: 0.6854427395739562 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 239, 'rf_max_depth': 9, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 1}. Best is trial 32 with value: 0.685607272266892.
# [I 2026-05-21 18:44:17,858] Trial 36 pruned.
# [I 2026-05-21 18:44:18,577] Trial 37 finished with value: 0.6855487847658382 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 311, 'rf_max_depth': 12, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 32 with value: 0.685607272266892.
# [I 2026-05-21 18:44:18,624] Trial 38 pruned.
# [I 2026-05-21 18:44:19,188] Trial 39 pruned.
# [I 2026-05-21 18:44:19,944] Trial 40 pruned.
# [I 2026-05-21 18:44:20,548] Trial 41 finished with value: 0.6847527858694111 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 260, 'rf_max_depth': 12, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 32 with value: 0.685607272266892.
# [I 2026-05-21 18:44:20,620] Trial 42 pruned.
# [I 2026-05-21 18:44:21,263] Trial 43 finished with value: 0.6871341204199494 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 300, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 2}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:21,722] Trial 44 finished with value: 0.6868272737357403 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 203, 'rf_max_depth': 9, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:22,134] Trial 45 finished with value: 0.6826347242910699 and parameters: {'scaler': 'robust', 'encoder': 'no_drop', 'model': 'rf', 'rf_n_estimators': 192, 'rf_max_depth': 10, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 2}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:22,195] Trial 46 pruned.
# [I 2026-05-21 18:44:22,557] Trial 47 pruned.
# [I 2026-05-21 18:44:23,072] Trial 48 finished with value: 0.6826213575903475 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 202, 'rf_max_depth': 18, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:23,630] Trial 49 pruned.
# [I 2026-05-21 18:44:23,688] Trial 50 pruned.
# [I 2026-05-21 18:44:24,162] Trial 51 finished with value: 0.68572151926824 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 216, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:24,437] Trial 52 finished with value: 0.6832690804928012 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 108, 'rf_max_depth': 10, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:24,904] Trial 53 finished with value: 0.6834925150050142 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 206, 'rf_max_depth': 8, 'rf_min_samples_split': 15, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:25,326] Trial 54 finished with value: 0.683115059470893 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 168, 'rf_max_depth': 11, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 2}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:25,989] Trial 55 pruned.
# [I 2026-05-21 18:44:26,788] Trial 56 pruned.
# [I 2026-05-21 18:44:26,875] Trial 57 pruned.
# [I 2026-05-21 18:44:27,266] Trial 58 finished with value: 0.6858042653041811 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 175, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:27,574] Trial 59 finished with value: 0.6839684162100923 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 128, 'rf_max_depth': 9, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:27,970] Trial 60 pruned.
# [I 2026-05-21 18:44:28,400] Trial 61 finished with value: 0.6856756910734014 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 187, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:28,816] Trial 62 finished with value: 0.6860258193126263 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 180, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:29,220] Trial 63 pruned.
# [I 2026-05-21 18:44:29,699] Trial 64 finished with value: 0.6856607181366724 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 212, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:30,196] Trial 65 finished with value: 0.685993829041302 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 223, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:30,254] Trial 66 pruned.
# [I 2026-05-21 18:44:30,749] Trial 67 finished with value: 0.6839674205324048 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 217, 'rf_max_depth': 10, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 2}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:31,177] Trial 68 finished with value: 0.6860258193126263 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 180, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:31,470] Trial 69 pruned.
# [I 2026-05-21 18:44:31,847] Trial 70 pruned.
# [I 2026-05-21 18:44:32,287] Trial 71 finished with value: 0.6856335331100865 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 188, 'rf_max_depth': 9, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:32,768] Trial 72 finished with value: 0.6857704823187628 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 221, 'rf_max_depth': 9, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:33,343] Trial 73 finished with value: 0.6847656033000433 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 248, 'rf_max_depth': 10, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:33,816] Trial 74 finished with value: 0.6842578604786361 and parameters: {'scaler': 'robust', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 226, 'rf_max_depth': 8, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 2}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:34,180] Trial 75 pruned.
# [I 2026-05-21 18:44:34,251] Trial 76 pruned.
# [I 2026-05-21 18:44:34,820] Trial 77 finished with value: 0.6868572045812964 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 260, 'rf_max_depth': 9, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:35,460] Trial 78 pruned.
# [I 2026-05-21 18:44:35,513] Trial 79 pruned.
# [I 2026-05-21 18:44:35,993] Trial 80 pruned.
# [I 2026-05-21 18:44:36,465] Trial 81 finished with value: 0.6869515235551769 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 215, 'rf_max_depth': 9, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:36,816] Trial 82 pruned.
# [I 2026-05-21 18:44:37,283] Trial 83 finished with value: 0.6870740362804827 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 203, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:37,776] Trial 84 finished with value: 0.6853751277566165 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 204, 'rf_max_depth': 10, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:38,275] Trial 85 pruned.
# [I 2026-05-21 18:44:38,802] Trial 86 pruned.
# [I 2026-05-21 18:44:39,259] Trial 87 pruned.
# [I 2026-05-21 18:44:39,697] Trial 88 finished with value: 0.6853748017197681 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 176, 'rf_max_depth': 10, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 43 with value: 0.6871341204199494.
# [I 2026-05-21 18:44:40,277] Trial 89 finished with value: 0.6885378291777221 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 268, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 89 with value: 0.6885378291777221.
# [I 2026-05-21 18:44:40,337] Trial 90 pruned.
# [I 2026-05-21 18:44:40,974] Trial 91 finished with value: 0.6888378774059756 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 299, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:41,609] Trial 92 finished with value: 0.6857678415807172 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 284, 'rf_max_depth': 10, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:42,247] Trial 93 finished with value: 0.6874906674093877 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 298, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:42,852] Trial 94 pruned.
# [I 2026-05-21 18:44:43,548] Trial 95 pruned.
# [I 2026-05-21 18:44:44,120] Trial 96 pruned.
# [I 2026-05-21 18:44:44,725] Trial 97 finished with value: 0.6860222659859494 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 249, 'rf_max_depth': 10, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 2}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:45,373] Trial 98 pruned.
# [I 2026-05-21 18:44:45,888] Trial 99 pruned.
# [I 2026-05-21 18:44:45,944] Trial 100 pruned.
# [I 2026-05-21 18:44:46,490] Trial 101 pruned.
# [I 2026-05-21 18:44:47,050] Trial 102 finished with value: 0.6853122534217986 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 254, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 2}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:47,813] Trial 103 finished with value: 0.6862939002953695 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 310, 'rf_max_depth': 10, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:48,530] Trial 104 finished with value: 0.6877580329421005 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 309, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:49,287] Trial 105 finished with value: 0.6858149111136014 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 311, 'rf_max_depth': 11, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:50,010] Trial 106 pruned.
# [I 2026-05-21 18:44:50,822] Trial 107 pruned.
# [I 2026-05-21 18:44:51,466] Trial 108 finished with value: 0.687567978126482 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 288, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:52,141] Trial 109 finished with value: 0.6871171181806346 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 291, 'rf_max_depth': 10, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:52,249] Trial 110 pruned.
# [I 2026-05-21 18:44:53,006] Trial 111 finished with value: 0.6872341759236132 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 289, 'rf_max_depth': 10, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:53,639] Trial 112 finished with value: 0.6875208993990086 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 289, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:54,277] Trial 113 finished with value: 0.6874482578754189 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 290, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:54,968] Trial 114 pruned.
# [I 2026-05-21 18:44:55,599] Trial 115 finished with value: 0.6868851399249916 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 270, 'rf_max_depth': 10, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:56,235] Trial 116 pruned.
# [I 2026-05-21 18:44:56,997] Trial 117 pruned.
# [I 2026-05-21 18:44:57,772] Trial 118 pruned.
# [I 2026-05-21 18:44:58,427] Trial 119 pruned.
# [I 2026-05-21 18:44:58,478] Trial 120 pruned.
# [I 2026-05-21 18:44:59,121] Trial 121 finished with value: 0.6869591237877586 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 269, 'rf_max_depth': 10, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:44:59,748] Trial 122 finished with value: 0.687567978126482 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 288, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:45:00,396] Trial 123 finished with value: 0.6870312566900485 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 283, 'rf_max_depth': 10, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:45:01,109] Trial 124 finished with value: 0.6874884554633307 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 287, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:45:01,859] Trial 125 finished with value: 0.6877468008175247 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 307, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:45:02,533] Trial 126 finished with value: 0.6869080113517527 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 307, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 2}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:45:03,184] Trial 127 pruned.
# [I 2026-05-21 18:45:03,820] Trial 128 finished with value: 0.6884506724296237 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 294, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 91 with value: 0.6888378774059756.
# [I 2026-05-21 18:45:04,516] Trial 129 pruned.
# [I 2026-05-21 18:45:05,162] Trial 130 finished with value: 0.6888449383971311 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 298, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:05,807] Trial 131 finished with value: 0.6888449383971311 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 298, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:06,427] Trial 132 finished with value: 0.6885115564658486 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 282, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:07,081] Trial 133 finished with value: 0.6888449383971311 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 298, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:07,496] Trial 134 pruned.
# [I 2026-05-21 18:45:08,173] Trial 135 finished with value: 0.6879987592451597 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 315, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:08,757] Trial 136 pruned.
# [I 2026-05-21 18:45:09,445] Trial 137 pruned.
# [I 2026-05-21 18:45:10,123] Trial 138 finished with value: 0.6871150971626983 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 315, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:10,185] Trial 139 pruned.
# [I 2026-05-21 18:45:10,803] Trial 140 pruned.
# [I 2026-05-21 18:45:11,413] Trial 141 finished with value: 0.6887382401393694 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 279, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:12,013] Trial 142 finished with value: 0.6886379899842012 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 278, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:12,623] Trial 143 finished with value: 0.6883318868433397 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 264, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:13,163] Trial 144 pruned.
# [I 2026-05-21 18:45:13,761] Trial 145 finished with value: 0.6887771121590407 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 280, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:14,360] Trial 146 finished with value: 0.6886379899842012 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 278, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:14,979] Trial 147 finished with value: 0.6859915808448684 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 277, 'rf_max_depth': 10, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:15,492] Trial 148 pruned.
# [I 2026-05-21 18:45:15,550] Trial 149 pruned.
# [I 2026-05-21 18:45:16,156] Trial 150 finished with value: 0.6874866044226612 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 276, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:16,815] Trial 151 finished with value: 0.6882048488965025 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 311, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:17,482] Trial 152 finished with value: 0.6881362158337478 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 313, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:18,183] Trial 153 finished with value: 0.6870350786598869 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 328, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:18,795] Trial 154 pruned.
# [I 2026-05-21 18:45:19,516] Trial 155 finished with value: 0.686077155175889 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 312, 'rf_max_depth': 10, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:20,181] Trial 156 pruned.
# [I 2026-05-21 18:45:20,756] Trial 157 pruned.
# [I 2026-05-21 18:45:21,347] Trial 158 finished with value: 0.6873411044288121 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 279, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 2}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:21,988] Trial 159 finished with value: 0.6860584209329502 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 305, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 2}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:22,534] Trial 160 pruned.
# [I 2026-05-21 18:45:23,177] Trial 161 pruned.
# [I 2026-05-21 18:45:23,811] Trial 162 finished with value: 0.6888378774059756 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 299, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:24,497] Trial 163 finished with value: 0.6871962611777513 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 320, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:25,114] Trial 164 pruned.
# [I 2026-05-21 18:45:25,733] Trial 165 pruned.
# [I 2026-05-21 18:45:26,420] Trial 166 finished with value: 0.6873413127147487 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 295, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:27,025] Trial 167 pruned.
# [I 2026-05-21 18:45:27,630] Trial 168 finished with value: 0.6872577547705017 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 283, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:27,700] Trial 169 pruned.
# [I 2026-05-21 18:45:28,363] Trial 170 pruned.
# [I 2026-05-21 18:45:29,036] Trial 171 finished with value: 0.6876607305994077 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 311, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:29,676] Trial 172 finished with value: 0.6885753732176731 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 305, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:30,350] Trial 173 pruned.
# [I 2026-05-21 18:45:31,021] Trial 174 finished with value: 0.6881274114836085 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 316, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:31,714] Trial 175 finished with value: 0.6881955339509155 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 321, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:32,433] Trial 176 finished with value: 0.6886906760798535 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 338, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:33,080] Trial 177 pruned.
# [I 2026-05-21 18:45:33,656] Trial 178 pruned.
# [I 2026-05-21 18:45:34,227] Trial 179 finished with value: 0.6881244884862749 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 263, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:34,967] Trial 180 pruned.
# [I 2026-05-21 18:45:35,592] Trial 181 finished with value: 0.6885943276709403 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 295, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:36,315] Trial 182 pruned.
# [I 2026-05-21 18:45:36,911] Trial 183 pruned.
# [I 2026-05-21 18:45:37,525] Trial 184 finished with value: 0.6871613163597627 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 282, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:38,181] Trial 185 pruned.
# [I 2026-05-21 18:45:38,230] Trial 186 pruned.
# [I 2026-05-21 18:45:39,010] Trial 187 pruned.
# [I 2026-05-21 18:45:39,593] Trial 188 pruned.
# [I 2026-05-21 18:45:40,200] Trial 189 pruned.
# [I 2026-05-21 18:45:40,815] Trial 190 finished with value: 0.6875524842833212 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 284, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:41,600] Trial 191 pruned.
# [I 2026-05-21 18:45:42,270] Trial 192 finished with value: 0.6880329371040776 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 317, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:42,997] Trial 193 pruned.
# [I 2026-05-21 18:45:43,669] Trial 194 pruned.
# [I 2026-05-21 18:45:44,330] Trial 195 pruned.
# [I 2026-05-21 18:45:45,013] Trial 196 finished with value: 0.6885416597964092 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 305, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:45,627] Trial 197 finished with value: 0.6877274000151231 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 289, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:46,086] Trial 198 pruned.
# [I 2026-05-21 18:45:46,712] Trial 199 pruned.
# [I 2026-05-21 18:45:47,273] Trial 200 pruned.
# [I 2026-05-21 18:45:47,928] Trial 201 finished with value: 0.6885381584955589 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 307, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:48,586] Trial 202 finished with value: 0.6884116353547546 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 308, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:49,211] Trial 203 finished with value: 0.6884506724296237 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 294, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:49,831] Trial 204 finished with value: 0.6876598225915999 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 293, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:50,457] Trial 205 pruned.
# [I 2026-05-21 18:45:51,079] Trial 206 finished with value: 0.6883647366610282 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 287, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:51,153] Trial 207 pruned.
# [I 2026-05-21 18:45:51,784] Trial 208 pruned.
# [I 2026-05-21 18:45:52,357] Trial 209 finished with value: 0.6881955846823485 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 261, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:52,961] Trial 210 finished with value: 0.6875306862393864 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 276, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 2}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:53,590] Trial 211 finished with value: 0.6884538190363798 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 293, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:54,223] Trial 212 finished with value: 0.6885019442286031 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 292, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:54,810] Trial 213 pruned.
# [I 2026-05-21 18:45:55,492] Trial 214 finished with value: 0.6872387666944763 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 298, 'rf_max_depth': 10, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:56,104] Trial 215 pruned.
# [I 2026-05-21 18:45:56,763] Trial 216 finished with value: 0.6886582797253087 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 304, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:57,387] Trial 217 pruned.
# [I 2026-05-21 18:45:58,012] Trial 218 finished with value: 0.6872746148780828 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 296, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:58,679] Trial 219 finished with value: 0.6877580329421005 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 309, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:58,742] Trial 220 pruned.
# [I 2026-05-21 18:45:59,367] Trial 221 finished with value: 0.6884129286258668 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 286, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:45:59,984] Trial 222 finished with value: 0.6887382401393694 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 279, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:46:00,619] Trial 223 pruned.
# [I 2026-05-21 18:46:01,636] Trial 224 finished with value: 0.688834880133768 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 496, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 130 with value: 0.6888449383971311.
# [I 2026-05-21 18:46:02,556] Trial 225 pruned.
# [I 2026-05-21 18:46:03,438] Trial 226 finished with value: 0.6888946744159334 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 418, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 226 with value: 0.6888946744159334.
# [I 2026-05-21 18:46:04,052] Trial 227 pruned.
# [I 2026-05-21 18:46:04,970] Trial 228 finished with value: 0.6880574546261183 and parameters: {'scaler': 'minmax', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 443, 'rf_max_depth': 9, 'rf_min_samples_split': 20, 'rf_min_samples_leaf': 1}. Best is trial 226 with value: 0.6888946744159334.
# [I 2026-05-21 18:46:05,828] Trial 229 pruned.
# [I 2026-05-21 18:46:06,811] Trial 230 pruned.
# [I 2026-05-21 18:46:07,966] Trial 231 pruned.
# [I 2026-05-21 18:46:08,970] Trial 232 finished with value: 0.6889408619000476 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 493, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:10,013] Trial 233 finished with value: 0.6889129055412441 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 494, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:11,031] Trial 234 finished with value: 0.6888586800558023 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 495, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:12,024] Trial 235 finished with value: 0.688757321693201 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 482, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:13,057] Trial 236 pruned.
# [I 2026-05-21 18:46:14,041] Trial 237 finished with value: 0.688757321693201 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 482, 'rf_max_depth': 9, 'rf_min_samples_split': 19, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:15,013] Trial 238 pruned.
# [I 2026-05-21 18:46:15,945] Trial 239 pruned.
# [I 2026-05-21 18:46:16,963] Trial 240 finished with value: 0.6887533729370787 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 496, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:17,988] Trial 241 finished with value: 0.6885728626989186 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 500, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:19,013] Trial 242 finished with value: 0.6879390132976877 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 500, 'rf_max_depth': 9, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:20,011] Trial 243 finished with value: 0.6887363705610341 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 491, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:21,090] Trial 244 finished with value: 0.6876250052810369 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 488, 'rf_max_depth': 10, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:22,071] Trial 245 finished with value: 0.6888154376138813 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 480, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:23,044] Trial 246 finished with value: 0.6876720887285366 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 469, 'rf_max_depth': 9, 'rf_min_samples_split': 17, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:24,047] Trial 247 finished with value: 0.6887846036598394 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 493, 'rf_max_depth': 9, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:25,097] Trial 248 finished with value: 0.6876559326391478 and parameters: {'scaler': 'std', 'encoder': 'drop_first', 'model': 'rf', 'rf_n_estimators': 493, 'rf_max_depth': 10, 'rf_min_samples_split': 18, 'rf_min_samples_leaf': 1}. Best is trial 232 with value: 0.6889408619000476.
# [I 2026-05-21 18:46:26,024] Trial 249 pruned.

# %%
# =========================================================
# Results
# =========================================================

print("\nBest average_precision:")
print(study.best_value)

print("\nBest Params:")
for k, v in study.best_params.items():
    print(f"{k}: {v}")
# Out:
# Best average_precision:
# 0.6889408619000476
#
# Best Params:
# scaler: std
# encoder: drop_first
# model: rf
# rf_n_estimators: 493
# rf_max_depth: 9
# rf_min_samples_split: 19
# rf_min_samples_leaf: 1

# %% [markdown]
# Best average_precision:
# 0.8608392756723857
#
# Best Params:
# scaler: std
# encoder: drop_first
# model: rf
# rf_n_estimators: 221
# rf_max_depth: 9
# rf_min_samples_split: 4
# rf_min_samples_leaf: 4

# %% [markdown]
# MLflow Experiment
#     └── Optuna Study
#             └── Trial Loop
#                     ├── Choose hyperparameters (Bayesian optimization)
#                     ├── Build preprocessing + model pipeline
#                     ├── Run Cross Validation
#                     ├── Compute ROC-AUC
#                     ├── Report metric to Optuna
#                     ├── Optuna decides:
#                     │       ├── continue
#                     │       └── prune trial
#                     └── MLflow logs params + metrics
#             └── Best trial selected
#     └── Train best model on full training data
#     └── Save model to MLflow
