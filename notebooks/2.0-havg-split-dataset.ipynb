# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Splitting and Partition Management Pipeline

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src import data_prep as prep

# %% [markdown]
# ## 1. Ingest Raw Dataset

# %%
csv = pd.read_csv("data/raw/Customer-Churn-Records.csv")

# %% [markdown]
# ## 2. Execute Stratified Train/Validation/Test Partitioning

# %%
# We perform a two-stage stratified split to preserve the distribution of our target variable `Exited`.

X_train, X_val, X_test, y_train, y_val, y_test = prep.create_stratified_splits(
    df=csv, 
    target_col="Exited", 
    test_size=0.2, 
    val_size=0.2, 
    random_state=43
)

# %%
# Optional: Keep track of your paired tuple structures if needed downstream
train = (X_train, y_train)
val = (X_val, y_val)
test = (X_test, y_test)

# %% [markdown]
# ## 3. Serialize and Export Data Splits

# %%
# Exporting raw feature distributions
feature_path = '../data/processed/raw_features'
prep.save_feature_splits(X_train, X_val, X_test, base_path=feature_path)

# %%
# Exporting target labels
target_path = '../data/processed/target'
prep.save_target_splits(y_train, y_val, y_test, base_path=target_path)
